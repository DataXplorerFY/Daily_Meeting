# %%
pip install yolov8
# Out:
# ...
#                                               0.0/953.4 kB ? eta -:--:--
#                                               0.0/953.4 kB ? eta -:--:--
#                                               10.2/953.4 kB ? eta -:--:--
#      -                                       30.7/953.4 kB 1.4 MB/s eta 0:00:01
#      -                                       30.7/953.4 kB 1.4 MB/s eta 0:00:01
#      ---                                   92.2/953.4 kB 655.4 kB/s eta 0:00:02
#      -----                                153.6/953.4 kB 766.6 kB/s eta 0:00:02
#      -----------                            276.5/953.4 kB 1.1 MB/s eta 0:00:01
#      --------------                         358.4/953.4 kB 1.3 MB/s eta 0:00:01
#      ----------------                       419.8/953.4 kB 1.3 MB/s eta 0:00:01
#      ------------------                     471.0/953.4 kB 1.3 MB/s eta 0:00:01
#      ------------------                     471.0/953.4 kB 1.3 MB/s eta 0:00:01
# ...

# %%
pip install sentencepiece
# Out:
# ...
#                                               0.0/977.5 kB ? eta -:--:--
#                                               0.0/977.5 kB ? eta -:--:--
#                                               0.0/977.5 kB ? eta -:--:--
#      --                                       61.4/977.5 kB ? eta -:--:--
#      --                                       61.4/977.5 kB ? eta -:--:--
#      ---                                   92.2/977.5 kB 751.6 kB/s eta 0:00:02
#      ---                                   92.2/977.5 kB 751.6 kB/s eta 0:00:02
#      ----                                 122.9/977.5 kB 554.9 kB/s eta 0:00:02
#      ----                                 122.9/977.5 kB 554.9 kB/s eta 0:00:02
#      -----                                153.6/977.5 kB 459.5 kB/s eta 0:00:02
#      -----                                153.6/977.5 kB 459.5 kB/s eta 0:00:02
#      -------                              194.6/977.5 kB 454.0 kB/s eta 0:00:02
# ...

# %%
pip uninstall pywinpty

# %%
pip install pywinpty<2
pip install fsspec==2023.3.0

# %%
import cv2
import numpy as np

# Load the 4 images
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')
img3 = cv2.imread('3.jpg')
img4 = cv2.imread('4.jpg')

# Create a list of images
images = [img1, img2, img3, img4]

# Preprocess the images
for i, img in enumerate(images):
# Resize the image
    img = cv2.resize(img, (640, 480))

# Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


# Apply thresholding
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    
# Convert the image to grayscale
    gray = cv2.cvtColor(img_fg, cv2.COLOR_BGR2GRAY)
    
# Apply thresholding
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate through the contours and draw a bounding rectangle around each orange
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(img_fg, (x, y), (x+w, y+h), (0, 255, 0), 2)

# Normalize the image
    img_fg = cv2.normalize(img_fg, None, 0.0, 1.0, cv2.NORM_MINMAX)

    # Save the preprocessed image
    cv2.imwrite(f'preprocessed_image_{i+1}.jpg', img_fg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6112/1269399183.py in <module>
#      25
#      26 # Convert the image to grayscale
# ---> 27     gray = cv2.cvtColor(img_fg, cv2.COLOR_BGR2GRAY)
#      28
#      29 # Apply thresholding
#
# NameError: name 'img_fg' is not defined

# %%
import cv2
import numpy as np

# Load the 4 images
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')
img3 = cv2.imread('3.jpg')
img4 = cv2.imread('4.jpg')

# Create a list of images
images = [img1, img2, img3, img4]

# Preprocess the images
for i, img in enumerate(images):
    # Resize the image
    img = cv2.resize(img, (640, 480))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply thresholding
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    
    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Iterate through the contours and draw a bounding rectangle around each orange
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    # Normalize the image
    img = cv2.normalize(img, None, 0.0, 1.0, cv2.NORM_MINMAX)
    
    # Save the preprocessed image
    cv2.imwrite(f'preprocessed_image_{i+1}.jpg', img)

# %%
import cv2
import numpy as np

# Load the 4 images
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')
img3 = cv2.imread('3.jpg')
img4 = cv2.imread('4.jpg')

# Create a list of images
images = [img1, img2, img3, img4]

# Preprocess the images
for i, img in enumerate(images):
    # Resize the image
    img = cv2.resize(img, (640, 480))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply thresholding
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    
    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Iterate through the contours and draw a bounding rectangle around each orange
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    # Save the preprocessed image
    cv2.imwrite(f'preprocessed_image_{i+1}.jpg', img)

# %%
import cv2
import numpy as np

# Load the 4 images
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')
img3 = cv2.imread('3.jpg')
img4 = cv2.imread('4.jpg')

# Create a list of images
images = [img1, img2, img3, img4]

# Preprocess the images
for i, img in enumerate(images):
    # Resize the image
    img = cv2.resize(img, (640, 480))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply thresholding
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    
    # Use the threshold image as a mask to separate the foreground from the background
    img_fg = cv2.bitwise_and(img, img, mask=thresh)
    
    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Iterate through the contours and draw a bounding rectangle around each orange
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(img_fg, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    # Save the preprocessed image
    cv2.imwrite(f'preprocessed_image_{i+1}.jpg', img_fg)

# %%
import cv2
import numpy as np

# Load the 4 images
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')
img3 = cv2.imread('3.jpg')
img4 = cv2.imread('4.jpg')

# Create a list of images
images = [img1, img2, img3, img4]

# Preprocess the images
for i, img in enumerate(images):
    # Resize the image
    img = cv2.resize(img, (640, 480))
    
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    # Define the range of orange color in HSV
    lower_orange = np.array([10, 100, 100])
    upper_orange = np.array([20, 255, 255])
    
    # Threshold the HSV image to get only orange colors
    mask = cv2.inRange(hsv, lower_orange, upper_orange)
    
    # Apply Canny edge detection to the thresholded image
    edges = cv2.Canny(mask, 100, 200)
    
    # Find contours
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Iterate through the contours and draw a bounding rectangle around each orange
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    # Save the preprocessed image
    cv2.imwrite(f'preprocessed_image_{i+1}.jpg', img)
